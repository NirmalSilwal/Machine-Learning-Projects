# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# sigmoid function

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
test=np.arange(-6,6,0.01)
plt.plot(test, sigmoid(test),linewidth=1)
plt.grid(1)
plt.show()
